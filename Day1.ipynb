# %%
int(2.9)
# Out:
# 2

# %%
Dhrumil_age = 17

if Dhrumil_age > 18:
    print("Dhrumil has grown big")
elif Dhrumil_age < 18:
    print("Dhrumil is below 18")
else:
    print("Dhrumil is 18")
# Out:
# Dhrumil is below 18

# %%
age = int(input("Enter your Age Dhrumil: "))

if (age > 10):
    print("Dhrumil youre grown big")
# Out:
# Dhrumil youre grown big

# %%
choice = input("Dhrumil what would you like to have today? ")
if (choice == 'pizza'):
    print("Pizzas are tasty but they are not healthy")
elif (choice == 'Roti'):
    print("But you'll have to make it yourself")
else:
    print("This choice is invalid for you")
# Out:
# This choice is invalid for you

# %%
age = int(input("Dhrumil Enter your age: "))20

if age >= 18 and age <= 20:
    print("Therefore product will cost you ", age * 0.90, " then you'll grow old and no discount for you")
# Out:
# Therefore product will cost you  18.0  then you'll grow old and no discount for you

# %% [markdown]
# #### While loops

# %%
GraduationAge = 20
i = 1
while (i < GraduationAge):
    if (i == GraduationAge):
        print("You are Graduated")
    i = i + 1
else:
    print(age)
    if (i == GraduationAge):
        print("Bro you got Graduated")
# Out:
# 20
# Bro you got Graduated

# %%
FirstArray = [23,235,623,523,235,2362,"Name", "SecondName", "ThirdName"]
print(FirstArray)
# Out:
# [23, 235, 623, 523, 235, 2362, 'Name', 'SecondName', 'ThirdName']

# %%
for i in FirstArray:
    print(i, end=" ")
# Out:
# 23 235 623 523 235 2362 Name SecondName ThirdName

# %%
FirstArray[len(FirstArray) - 4]
# Out:
# 2362

# %%
for i in FirstArray[len(FirstArray) - 2]:
    print(i, end='  ')
# Out:
# S  e  c  o  n  d  N  a  m  e

# %%
for i in range(0, len(FirstArray)):
    print(FirstArray[i])
# Out:
# 23
# 235
# 623
# 523
# 235
# 2362
# Name
# SecondName
# ThirdName

# %%
for i in range(20, 201, 10):
    print(i, end=' ')
# Out:
# 20 30 40 50 60 70 80 90 100 110 120 130 140 150 160 170 180 190 200

# %%
for i in range(0, 6):
    for j in range(0, 6):
        if (j <= i):
            print('*', end=' ')
    print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %%
for i in range(0, 6):
    for j in range(0, 6):
        if (j >= i):
            print('*', end=' ')
    print('')
# Out:
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
